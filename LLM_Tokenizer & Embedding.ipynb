# %% [markdown]
# ---
#
# # LLM_Tokenizer and Embedding
# *From Language to Meaningful Vector Representation*
#
# ---
#
# ## 1. Tokenizer: 언어를 모델이 이해할 수 있는 단위로 자르는 행위
#
# 자연어는 연속적인 의미의 흐름으로 이루어져 있다. 그러나 기계는 이 흐름을 그대로 다룰 수 없다.  따라서 **언어를 어떤 단위로 끊고 표현할지를 결정하는 전처리 기제**가 필요하다.
# 이 단위를 "토큰(token)"이라 하며, 이 작업을 수행하는 도구를 **Tokenizer**라고 부른다.
#
# ### 🔹 토크나이저는 단순한 분할 기계가 아니다
# - '단어 기준'일 수도, '문자 기준'일 수도, 혹은 그 중간인 **서브워드(subword)** 기준일 수도 있다.
# - BPE(Byte Pair Encoding), WordPiece, SentencePiece 등은 인간 언어의 **패턴성과 압축 가능성**을 이용한 전략들이다.
# - 핵심은: **의미의 단위와 연산 효율성 사이의 절충**을 찾는 일이다.
#
# > "Tokenizer는 인간의 문장을 숫자의 나열로 변환하는 과정이 아니라, 의미의 가장 작은 조각들을 기계가 다룰 수 있도록 재해석하는 첫 번째 필터이다."
#
# ### 🔸 수학적 시각 (정보이론 관점)
#
# 좋은 토크나이저는 모델이 학습하기 쉽게 만드는 분할을 수행한다. 이때, 자주 등장하는 패턴을 재사용하는 방식은 **엔트로피 감소**와 연결된다.
#
# $$
# H(T) = -\sum_{i} p(t_i) \log p(t_i)
# $$
#
# - 여기서 $T$는 토큰 시퀀스이며, $p(t_i)$는 토큰 $t_i$의 등장 확률이다.
# - 자주 등장하는 서브워드를 병합하면 엔트로피를 줄일 수 있어 모델 학습이 안정된다.
#
# ---

# %% [markdown]
# ## 2. Embedding: 토큰에 의미를 부여하는 수치적 재구성
#
# 우리가 말하는 ‘단어’ 하나하나는 모델 입장에서는 그대로 이해할 수 없다. 그래서 단어를 숫자의 집합으로 바꾸어야 하고, 이 과정을 벡터로 변환한다고 표현한다.
# 예를 들어 “apple”이라는 단어는 [0.12, -1.03, 0.57, ..., 0.88] 같은 숫자 리스트로 바뀌어 저장된다.
#
# > 토크나이저가 언어를 잘게 나누는 역할이라면, 임베딩은 그렇게 나눠진 조각들 사이에 의미적 유사성과 차이를 표현할 수 있도록 구조를 부여하는 과정이다.
#
#
# ### 🔹 정의: 의미 공간 위로의 매핑
#
# 각 토큰 $t_i$는 다음과 같은 함수 $f$에 의해 벡터 공간의 점으로 변환된다.
#
# $$
# f: t_i \mapsto \mathbf{v}_i \in \mathbb{R}^d
# $$
#
# 즉, 토큰은 $d$차원의 벡터로 표현되며, 이 벡터들 간의 거리나 방향은 의미적인 유사성을 내포한다.
#
# ### 🔹 유사성 계산
#
# 자주 사용되는 의미 유사성 측도는 **코사인 유사도**이다.
#
# $$
# \text{sim}(\mathbf{v}_i, \mathbf{v}_j) = \frac{\mathbf{v}_i \cdot \mathbf{v}_j}{\|\mathbf{v}_i\| \|\mathbf{v}_j\|}
# $$
#
# - 1에 가까울수록 유사한 의미를 가진다.
# - 이는 임베딩 공간이 단순한 임의의 숫자 공간이 아니라 **기하학적 관계**가 보존되는 구조적 공간임을 의미한다.
#
# > "Embedding은 언어를 공간 위로 펼쳐내는 작업이다. 단어들은 더 이상 기호가 아니라, 구조 속에서 관계를 맺는 점(point)이 된다."
#
# ### 🔸 학습 가능한 파라미터로서의 임베딩
#
# 임베딩은 고정된 것이 아니라, 학습된다. 보통은 임베딩 행렬 $E \in \mathbb{R}^{V \times d}$를 사용한다.
#
# $$
# \mathbf{v}_i = E[i]
# $$
#
# - $V$: vocabulary size
# - $d$: embedding 차원 수
# - 각 token ID $i$는 이 행렬의 한 row를 참조한다.
#
# 하지만 이 값은 역전파(backpropagation)에 의해 계속해서 **업데이트**되며, 모델의 표현력을 구성하는 핵심 요소가 된다.
#
# ---
#
# ## 3. 토크나이저와 임베딩의 결합: 기호에서 의미로의 이동
#
# - Tokenizer는 **무한한 언어의 흐름**을 **유한한 조각들**로 쪼개고,
# - Embedding은 이 조각들에 **맥락 속 좌표**를 부여한다.
#
# 이 두 과정은 연결되어 있으나, 본질적으로 역할이 다르다.
#
# | 역할 | Tokenizer | Embedding |
# |------|-----------|-----------|
# | 목적 | 문장을 기계가 다룰 수 있는 조각으로 분리 | 조각들에 의미적 구조를 부여 |
# | 관점 | 구조화의 시작 | 구조화의 맥락화 |
# | 수학 | 확률 기반 분할 (엔트로피) | 벡터 공간 변환 ($\mathbb{R}^d$) |
# | 결과 | token id 시퀀스 | dense vector 시퀀스 |
#
# ---
#
# ## 4. 다음 주제로 이어지는 관문
#
# - **Positional Encoding**: 임베딩된 벡터에 ‘순서’라는 요소를 다시 불어넣는 작업
# - **Attention**: 벡터들 간의 관계를 동적으로 계산하며, 어떤 벡터가 다른 벡터에 얼마나 집중해야 하는지를 결정
# - **Transformer**: 토크나이저-임베딩-포지셔널 인코딩-어텐션이 하나의 유기적 구조로 작동하는 프레임워크
#
# ---
#
# > "Tokenizer는 언어의 물리적 조각을 만들고, Embedding은 그 조각들에 의미의 방향을 부여한다. 이것은 기호에서 구조로, 구조에서 의미로 나아가는 여정이다."
#
# ---

# %% [markdown]
# ## example code

# %%
# 라이브러리 설치
# !pip install transformers torch

from transformers import AutoTokenizer, AutoModel
import torch

# 1. 한글을 지원하는 다국어 BERT 모델 선택
model_name = "bert-base-multilingual-cased"

# 2. 토크나이저와 모델 로드
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# 3. 분석할 한글 문장
sentence = "애플이 한국의 스타트업을 인수하려고 검토 중이다."

# 4. 문장을 토큰화하고 텐서로 변환
inputs = tokenizer(sentence, return_tensors="pt")

print("토큰 목록:")
print(tokenizer.convert_ids_to_tokens(inputs["input_ids"][0]))

# 5. 모델을 통해 임베딩 벡터 얻기
with torch.no_grad():
    outputs = model(**inputs)
    last_hidden_state = outputs.last_hidden_state  # [batch_size, seq_len, hidden_size]

print("\n 임베딩 벡터 (첫 토큰 [CLS]):")
print(last_hidden_state[0][0])  # [CLS] 토큰의 벡터 (문장 전체 요약 역할)
# Out:
# 🧩 토큰 목록:
# ['[CLS]', '애', '##플', '##이', '한국', '##의', '스', '##타', '##트', '##업을', '인', '##수', '##하', '##려', '##고', '검', '##토', '중', '##이다', '.', '[SEP]']
#
#  임베딩 벡터 (첫 토큰 [CLS]):
# tensor([-3.3541e-02, -7.7447e-02, -5.1991e-01,  1.0638e-01, -2.3364e-01,
#         -1.6034e-03,  3.4674e-02,  1.5600e-01, -1.2483e-01,  9.0397e-02,
#         -1.2571e-01, -2.0012e-02, -1.4079e-01,  2.2318e-01, -6.8688e-01,
#         -6.1220e-02, -3.3518e-02,  4.7368e-01, -8.7908e-02,  5.0817e-02,
#          1.4521e-01,  8.8102e-02,  2.5792e-02,  7.3641e-02,  1.2483e-01,
#         -3.9818e-01,  1.7606e-01,  1.0753e-01,  6.6053e-01,  1.2036e-01,
#         -1.6692e-01, -2.5440e-02, -1.4113e-01,  3.3779e-02, -1.6318e-01,
#          5.2532e-02, -2.0920e+00,  3.4625e-03, -1.2110e-01,  3.3744e-02,
#         -2.4640e-01,  5.0442e-02, -1.5856e-01,  3.6442e-02, -2.6870e-02,
#          1.4134e+00,  3.2669e-01, -1.1639e-01,  1.6142e+00,  1.9949e-01,
#         -7.8160e-02, -5.4737e-01,  2.8532e-02, -1.4704e+00,  1.8818e-02,
#          2.3959e-02, -7.8355e-02, -2.3517e-01,  1.1083e-01,  1.2170e-01,
#         -3.8945e-02,  6.0201e-02,  3.7341e-01, -3.0674e-02, -2.6367e-02,
#         -1.3758e-01, -4.3653e-02,  1.7448e-01, -2.2959e-01,  3.9929e-02,
#         -5.9622e-02,  2.9281e-01, -7.1614e-02,  6.7437e-02, -3.5097e-01,
#         -1.3411e-01, -9.2263e-02, -4.7020e-02, -4.4333e-01,  1.7528e-01,
#          2.7428e-01, -2.6366e-02, -3.1839e-01,  1.6816e-01, -3.6279e-02,
#          1.4267e-01, -1.1874e-01, -2.9560e-01, -1.5298e-01,  2.8785e-02,
#         -3.0927e-02, -1.0791e-01, -5.2531e-01, -1.7593e-01, -3.2016e-01,
#         -9.5879e-01,  1.0541e-01,  1.7821e-01,  2.4238e-01, -2.8390e-02,
#         -3.1605e-02,  1.6621e+00, -4.9946e-03, -1.1812e-01, -3.3069e+00,
#         -4.3574e-02, -7.5935e-02,  1.3898e-02,  6.6754e-01, -1.2398e-01,
#          4.6854e-01, -2.4221e-02,  3.5302e-02, -6.7963e-03,  1.9467e-01,
#          3.8728e-02, -2.5393e-01,  1.5852e-01, -2.6127e-01, -1.6657e-01,
#         -3.3962e-02, -7.4447e-02, -6.1283e-03, -1.5146e-01,  1.3721e-01,
#         -2.1320e-01,  1.1603e-01, -3.8219e-02,  2.6024e-01,  8.1975e-01,
#          8.1879e-02,  2.2419e+00,  9.9134e-02,  4.5712e-02,  6.7741e-02,
#          1.6175e+00,  4.1218e-02,  1.3618e-01,  2.9624e-01,  2.5312e-01,
#          2.7465e-01, -5.4417e-02, -3.8968e-01, -1.4692e-02, -1.3847e-01,
#         -1.2008e-01, -6.0609e-02,  4.5464e-03,  1.1553e-01, -7.9630e-02,
#          7.6411e-02, -1.2277e-01,  2.6923e-01,  2.5127e-01,  4.5075e-03,
#         -7.3914e-02, -1.5550e-01, -5.2394e-02,  5.6317e-02,  1.1053e-01,
#          1.5676e+00,  4.5829e-02, -2.6901e-01,  2.7349e-01, -3.6191e-02,
#          8.0752e-03, -4.7911e-02,  2.4238e-02, -2.5439e-01, -3.5734e-01,
#         -4.5922e-01, -2.8897e-01,  6.7207e-02, -2.5021e-02,  1.1338e-01,
#         -1.5622e-01, -1.9561e-01, -1.5829e-02, -1.0670e-01, -5.6844e-02,
#         -1.1775e-02, -4.7376e-02, -6.6760e-02,  1.8709e-02, -7.3029e-02,
#          8.6969e-03,  2.6817e-04,  1.5160e-01, -1.1982e-01, -1.4178e-01,
#          1.6283e-01,  1.4182e-01,  5.0707e-02, -1.7048e-01,  6.0705e-02,
#          3.7036e-02,  1.2866e-01,  1.8681e-01,  1.5049e-01,  9.0736e-02,
#          2.5750e-01,  2.2201e-01, -1.0739e-01, -5.1997e-02,  8.2865e-02,
#          2.9989e-01, -2.7888e-01, -2.1832e-01, -9.2039e-02,  4.3859e-03,
#         -8.8127e-02,  2.4334e-02,  9.9924e-01,  2.7481e-01,  2.3534e-01,
#         -1.1695e-01, -3.0224e-02, -1.2518e-01,  1.4133e-01, -2.0441e+00,
#         -1.1321e-01,  7.4636e-02, -3.8727e-02,  4.9070e-02, -7.8576e-02,
#         -2.8991e-02, -1.4870e-01,  4.3493e-01, -9.3266e-02, -4.7357e-02,
#          1.4087e-01,  1.0590e-01, -9.6104e-03, -1.9311e+00,  1.5876e-02,
#         -3.2592e-02, -8.3556e-02, -2.8093e-01, -4.6559e-02, -1.0982e-01,
#          1.5607e-01,  1.3570e-01, -7.7433e-02,  4.0288e-02,  3.4468e-01,
#         -2.4911e-01,  1.1913e+00,  7.0023e-03,  1.3231e-01, -2.4826e-01,
#          3.0772e-02, -2.5684e-01, -2.4747e-02, -1.9676e-01, -9.4981e-02,
#          6.0353e-02,  3.4954e-02, -2.7512e-01, -5.8720e-02, -2.1189e-01,
#         -1.3317e-01, -1.3013e-01,  1.1935e-01, -4.6263e-01, -5.2624e-02,
#         -2.3824e-01,  9.7610e-02,  6.7169e-02, -1.4672e-02, -1.4905e-01,
#          1.5414e-02,  8.0429e-02, -2.3295e-02,  1.0019e-01, -4.4947e-03,
#          5.0291e-02, -2.6417e-02,  2.9837e-01,  6.1906e-02, -5.7584e-02,
#          2.6989e-03,  4.4850e-02,  6.7494e-02,  1.8933e-01, -3.8441e-02,
#          1.9330e-02, -2.6866e-01, -7.9557e-02, -5.5879e-01, -1.0915e+00,
#         -2.4724e-01,  4.6180e-02,  1.5404e-02, -3.4770e-01, -2.8174e-02,
#         -5.1773e-02, -6.0860e-02, -6.2265e-02,  8.1535e-02, -5.6965e-02,
#         -4.0740e-02, -1.2281e-01, -4.7418e-02, -3.7530e-02, -1.7193e+00,
#          4.4920e-01,  1.3188e-01,  1.3592e-02,  2.5949e-02,  2.1919e-01,
#          8.9677e-02, -7.8279e-02,  1.9544e-01, -1.2538e-01, -2.2083e-01,
#         -2.4952e-01,  2.4940e-01,  1.5067e-01,  2.0985e-01,  2.0905e-02,
#         -7.0131e-02, -1.7888e+00,  5.7766e-02, -2.1067e-01, -7.5632e-03,
#         -2.0239e-01, -2.2697e-01,  1.5120e-01, -3.0552e-03,  2.2704e-01,
#          1.2156e-02, -4.5389e-02,  6.8674e-02, -2.7890e-02, -5.4477e-02,
#         -1.0657e-02, -2.1824e-02, -3.1416e-01,  5.0123e-02, -4.1134e-02,
#          1.8990e-02, -1.2725e-02,  5.7632e-02,  1.3344e-01, -5.5735e-02,
#         -1.7021e-01,  9.2218e-02, -3.1891e-01,  7.5329e-02,  2.9206e-01,
#          1.1299e-02,  1.4519e-01, -6.2084e-01,  1.4846e-01,  1.3090e-01,
#         -1.9535e-01, -1.1351e-01, -1.5571e-02, -4.1477e-02,  2.8944e-01,
#         -7.3800e-02,  2.0558e-01,  1.4198e-01, -8.4788e-02,  2.1796e-01,
#         -4.1834e-02,  8.0488e-02,  1.3083e-01, -6.0720e-03, -2.0009e-01,
#          1.7953e-01,  3.4164e-01,  6.3839e-03, -3.0201e-01, -1.0501e-01,
#         -1.4022e-01,  8.0571e-02, -1.5345e-01,  2.3970e-01, -5.2503e-03,
#         -3.4402e-02,  8.2196e-02, -1.5356e+00,  1.4859e-01,  1.2900e-01,
#         -1.4328e+00, -1.0384e-01, -5.8157e-02, -3.2282e-02, -4.9267e-02,
#          5.8986e-02,  9.6075e-02, -1.0965e-01,  9.8597e-02,  3.6434e-02,
#         -4.4125e-02, -5.4779e-02, -3.1950e-01,  1.0271e-01,  2.3322e-02,
#          3.2356e-01,  2.6707e-02,  3.5650e-01,  1.2784e-01, -1.1725e-01,
#         -1.8331e+00,  2.8104e-01,  1.3793e-01, -3.4791e-02,  1.8342e-01,
#          6.5828e-02,  2.1007e-01,  2.7132e-01,  3.8701e-01, -3.2285e-02,
#          5.9403e-02, -5.2118e-01,  8.5883e-02,  6.9927e-03, -5.2259e-01,
#          1.5071e-01,  7.7740e-01, -1.3671e-01, -2.7224e-01, -2.9082e-01,
#          2.7452e-03, -6.8003e-02, -3.4038e-01,  1.6472e-01,  3.5812e-02,
#         -1.0163e-01,  1.1996e-01,  2.6824e-01, -1.3403e+00, -2.0264e+00,
#          1.2579e+00,  6.9829e-03,  1.5770e-01,  4.1563e-02,  1.6376e+00,
#         -7.1260e-03, -5.9609e-02, -1.0032e-01,  7.3188e-03,  1.2054e-01,
#          3.2750e+00,  4.4352e-01,  2.0668e-02,  1.3961e+00,  1.2183e-01,
#          1.9411e-01, -2.9287e-01, -1.7072e+00, -2.0858e+00, -1.7824e-01,
#         -2.2149e-01, -1.0644e-01,  7.5833e-02,  5.6833e-02, -4.5493e-02,
#          1.4433e-01, -6.4997e-03,  3.0423e-01,  1.3197e-01, -1.0534e-01,
#          2.0150e-01, -6.8273e-02, -2.3111e-01, -1.0414e-01,  9.6144e-02,
#          8.3438e-01,  2.4986e-01,  1.3827e-01, -4.5506e-02, -4.4784e-01,
#         -2.1780e+00, -3.7165e-02, -6.8737e-02,  1.4985e-01, -2.2035e-01,
#          3.4180e-01, -1.0515e-01,  1.0358e-01, -1.0295e-01,  1.0934e-01,
#         -1.0006e-01,  4.0238e-02, -1.8637e-01,  6.3824e-02, -6.9580e-02,
#          1.0283e-01,  1.8109e-01, -2.0232e-02,  2.2093e+00,  1.5943e-02,
#         -6.8323e-02, -2.0386e-01,  1.2976e-01,  2.4059e-01, -7.0706e-02,
#         -5.8355e-02, -1.8996e-01, -1.0495e-02,  9.1968e-02, -1.2294e-02,
#         -5.5301e-02, -1.8297e-01, -2.0717e-01, -8.7363e-02, -1.5256e-03,
#          6.5782e-01,  4.6978e-01,  2.2152e-01, -8.2015e-01, -5.8057e-02,
#          2.2871e-01,  1.2056e-01,  1.0909e-01, -4.2043e-02,  8.0041e-02,
#          2.6210e-02, -6.1428e-02,  6.1144e-02, -1.8884e-01, -1.8182e-01,
#         -7.4780e-02, -1.1492e-01,  3.9317e-02, -9.8523e-02, -2.1669e-01,
#          1.1795e-02, -4.6737e-01, -3.6376e-02,  1.4970e+00, -2.5134e-02,
#         -1.4556e-01,  1.2212e+00,  1.1172e-01, -1.8178e-01,  2.2441e-01,
#          2.6496e-01,  1.6302e-01,  2.7722e-01, -1.3967e-01,  1.2362e-01,
#          3.1337e-01,  2.3112e-01, -7.4100e-02, -2.1098e-02, -5.3493e-02,
#         -8.4652e-02,  2.4549e-01,  1.0166e-01,  1.8994e-01, -3.5550e-04,
#         -2.0322e-01, -2.9758e-01, -1.3170e-01, -2.8192e-02,  7.9663e-02,
#          1.4897e-01,  4.1770e-01,  6.8353e-02, -1.3107e-01, -1.3621e-01,
#         -3.8719e-02,  9.5192e-02,  5.2749e-02, -1.5317e-01,  3.3013e-01,
#         -2.2997e-02, -9.3471e-02,  1.6099e-01, -2.0269e-02, -6.5747e-02,
#         -1.5983e-01,  6.4225e-02,  4.5874e-01,  1.3301e-01,  3.1808e-01,
#          7.7282e-02,  2.0698e-02, -1.7998e-01,  5.2629e-02, -3.4654e-01,
#         -3.6123e-02,  1.3228e-01, -4.2394e-03, -7.3459e-02, -1.1002e-01,
#          1.0098e-01,  2.5837e-01, -7.0725e-02, -4.8857e-02, -5.6947e-02,
#          2.3369e-01,  3.7297e-01,  2.1270e-01,  2.5341e-01, -1.2119e-01,
#          1.4879e-01, -1.5924e-01,  1.8228e-01, -8.9243e-02,  1.4436e-01,
#         -3.4270e-01,  1.3275e-01, -1.8160e-01, -4.1778e-01,  2.2526e-02,
#          8.1525e-02, -1.7491e-01,  5.1612e-02, -4.6786e-02,  4.4390e-02,
#         -2.0902e+00,  3.5787e-02, -2.4936e-02,  1.9075e-01, -3.4879e-02,
#          6.4710e-02,  1.0236e+00, -1.7128e-01,  1.3976e-01, -9.6583e-03,
#         -3.7280e-01,  1.7404e-01, -1.1081e-01,  6.6091e-02, -4.6827e-01,
#          1.3605e-01,  3.8282e-02,  2.0183e-01, -2.4212e-01, -2.3934e-02,
#         -1.7992e+00, -4.2002e-02, -8.3045e-02,  1.0801e-01, -1.8224e-02,
#         -5.0962e-02, -2.0170e-02, -5.2691e-02, -3.5622e-01,  6.8631e-02,
#         -1.8364e-01, -9.9342e-02,  1.5124e-01, -1.7736e-01,  1.9983e-02,
#         -6.0181e-02, -1.7968e-01, -2.1575e-02, -2.9153e-01,  1.7635e-01,
#          5.5282e-02, -2.2204e-02, -2.4253e-01,  2.6328e-01,  4.1226e-01,
#          2.1230e-01,  1.5706e-02,  7.0620e-02, -1.9296e-01,  5.3521e-02,
#         -1.7635e+00,  5.5259e-02, -5.9496e-03,  1.1155e-01, -1.2038e-01,
#          2.2017e-01, -7.4029e-03, -4.2008e-01, -1.8138e-01,  1.7266e-02,
#         -3.7549e-01,  4.7656e-02,  1.0844e-01,  2.6270e-01,  3.6994e-02,
#          2.0263e-01,  3.3006e-01,  3.4447e-01, -1.5599e-01, -8.5899e-02,
#         -4.5872e-03, -1.3894e-01,  5.6457e-01, -1.5737e-01,  2.0075e-01,
#          2.3780e-01, -3.8291e-02, -2.9103e-02,  5.6094e-02,  9.5782e-02,
#          3.9430e-02, -1.0844e+00,  1.6526e-01, -9.2217e-02, -2.3453e-02,
#         -9.2635e-02,  4.2705e-02, -3.9952e-02,  5.7869e-02,  3.5934e-01,
#          1.3359e-01,  4.5420e-01,  1.9541e+00,  6.8339e-02, -2.2342e-01,
#          2.1705e-01,  1.6706e-01, -1.5003e-01,  2.8840e-01, -2.0798e-01,
#          1.9615e+00, -9.6464e-02,  1.1014e-01, -1.4447e-02,  2.6504e-01,
#          1.6416e-01,  1.9780e+00, -5.6782e-02,  7.1529e-02,  3.1531e-02,
#          2.4235e-02, -1.7645e-01,  1.5985e-02, -1.5459e-01,  1.4974e-01,
#          4.8298e-02, -5.5480e-01,  9.1482e-02,  2.4015e-01,  3.1945e-01,
#         -7.0590e-02, -4.1078e-01, -6.0395e-02,  1.0355e-01, -1.1022e-01,
#          1.3274e-01,  9.0618e-02, -1.5510e-01, -8.5976e-02,  1.4468e-02,
#          1.6831e-01, -1.4095e-01,  1.6101e-02,  1.0362e-01,  2.8148e-02,
#         -5.9074e-02,  6.0528e-03,  2.2398e-01, -1.8696e-01,  1.4441e-01,
#          4.1678e-01, -4.9489e-02,  1.3773e-01, -7.0008e-02, -3.9612e-01,
#         -2.3745e-01, -2.2733e-01,  1.9473e-01,  1.0813e-01, -1.4924e-01,
#          4.1228e-01,  2.0091e-01,  7.0984e-03])
